# %% [markdown]
# <a href="https://colab.research.google.com/github/gmdeorozco/Probability-Problems-Python-Solutions/blob/main/6_Room_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Problem: In a school with 120 students, 60% of them enjoy playing basketball, and the rest do not. They are randomly split into two equally sized rooms. What is the probability that a student in the first room enjoys playing basketball?
#
# ---
#
#
# # 2. Standard Solution:
#
# ![p6.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# # 3. Programing Solution

# %%
def room_assignment(hobbie_prob, room_prob):
  return hobbie_prob * room_prob

# %% [markdown]
# # 4. Testing

# %%
prob = room_assignment(0.60, 0.50)
assert prob == 0.30, f'Incorrect if 60% enjoy play basketball and room are equaly sized, it should be 0.30, returned:{prob}'

print('Probability computed correctly')
# Out:
# Probability computed correctly

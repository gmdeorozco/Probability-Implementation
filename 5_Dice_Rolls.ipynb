# %% [markdown]
# <a href="https://colab.research.google.com/github/gmdeorozco/Probability-Problems-Python-Solutions/blob/main/5_Dice_Rolls.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Problem: If you roll a fair six-sided die twice, what is the probability of getting a 4 on the first roll and a 3 on the second roll? Assume the rolls are independent.
#
# ---
#
#
# # 2. Standard Solution:
#
# ![p5.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# # 3. Programing Solution

# %%
def probability_of_expected_sequence_of_dice_numbers(n_sequence:int=2) -> float:
  prob_per_roll= 1/6
  if n_sequence == 1:
    return prob_per_roll
  return prob_per_roll * probability_of_expected_sequence_of_dice_numbers(n_sequence-1)

# %% [markdown]
# ## 4. Testing

# %%
prob = probability_of_expected_sequence_of_dice_numbers(2)
assert prob == 1/36, f'Incorrect, the probability of getting a 4 and a 3 is {1/36}, returned: {prob}'

prob = probability_of_expected_sequence_of_dice_numbers(3)
assert prob == 1/(6**3), f'Incorrect, the probability of getting a 4 and a 3 is {1/(6**3)}, returned: {prob}'

print('Computed probability correctly')
# Out:
# Computed probability correctly
